# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import warnings

# plt.style.use('seaborn')
# plt.style.use('seaborn-colorblind') #alternative
plt.rcParams['figure.figsize'] = [8, 4.5]
plt.rcParams['figure.dpi'] = 300
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from datetime import datetime
import backtrader as bt
import pandas as pd 
import yfinance as yf

# %%
class SmaSignal(bt.Signal):
    params = (('period', 20), )
    
    def __init__(self):
        self.lines.signal = self.data - bt.ind.SMA(period=self.p.period)

# %%
data = bt.feeds.PandasData(dataname=yf.download('VOO', '2018-01-01', '2022-02-22'))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
cerebro = bt.Cerebro(stdstats = False)

cerebro.adddata(data)
cerebro.broker.setcash(1000.0)
cerebro.add_signal(bt.SIGNAL_LONG, SmaSignal)
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)

# %%
print(f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
cerebro.run()
print(f'Final Portfolio Value: {cerebro.broker.getvalue():.2f}')
# Out:
# Starting Portfolio Value: 1000.00
# Final Portfolio Value: 1056.93

# %%
cerebro.plot(iplot=True, volume=False)
# Out:
# <img src="data:image/png;base64,..." width="2400">
# [[<Figure size 2400x1350 with 3 Axes>]]

# %%
class SmaStrategy(bt.Strategy):
    params = (('ma_period', 20), )

    def __init__(self):
        # keep track of close price in the series
        self.data_close = self.datas[0].close

        # keep track of pending orders/buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None

        # add a simple moving average indicator
        self.sma = bt.ind.SMA(self.datas[0],
                              period=self.params.ma_period)
        
    def log(self, txt):
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f'BUY EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Commission: {order.executed.comm:.2f}')
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(f'SELL EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Commission: {order.executed.comm:.2f}')

        # report failed order
        elif order.status in [order.Canceled, order.Margin, 
                              order.Rejected]:
            self.log('Order Failed')

        # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log(f'OPERATION RESULT --- Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}')

    def next(self):
        # do nothing if an order is pending
        if self.order:
            return
 # check if there is already a position
        if not self.position:
            # buy condition
            if self.data_close[0] > self.sma[0]:
                self.log(f'BUY CREATED --- Price: {self.data_close[0]:.2f}')
                self.order = self.buy()
        else:
            # sell condition
            if self.data_close[0] < self.sma[0]:            
                self.log(f'SELL CREATED --- Price: {self.data_close[0]:.2f}')
                self.order = self.sell()

# %%
cerebro = bt.Cerebro(stdstats = False)

cerebro.adddata(data)
cerebro.broker.setcash(1000.0)
cerebro.addstrategy(SmaStrategy)
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)

# %%
print(f'Starting Portfolio Value: {cerebro.broker.getvalue():.2f}')
cerebro.run()
print(f'Final Portfolio Value: {cerebro.broker.getvalue():.2f}')
# Out:
# Starting Portfolio Value: 1000.00
# 2018-01-30, BUY CREATED --- Price: 258.75
# 2018-01-31, BUY EXECUTED --- Price: 259.83, Cost: 259.83, Commission: 0.00
# 2018-02-02, SELL CREATED --- Price: 253.19
# 2018-02-05, SELL EXECUTED --- Price: 251.26, Cost: 259.83, Commission: 0.00
# 2018-02-05, OPERATION RESULT --- Gross: -8.57, Net: -8.57
# 2018-02-23, BUY CREATED --- Price: 252.49
# 2018-02-26, BUY EXECUTED --- Price: 253.56, Cost: 253.56, Commission: 0.00
# 2018-03-01, SELL CREATED --- Price: 246.05
# 2018-03-02, SELL EXECUTED --- Price: 244.24, Cost: 253.56, Commission: 0.00
# 2018-03-02, OPERATION RESULT --- Gross: -9.32, Net: -9.32
# 2018-03-05, BUY CREATED --- Price: 250.20
# 2018-03-06, BUY EXECUTED --- Price: 251.22, Cost: 251.22, Commission: 0.00
# 2018-03-19, SELL CREATED --- Price: 249.61
# 2018-03-20, SELL EXECUTED --- Price: 249.99, Cost: 251.22, Commission: 0.00
# 2018-03-20, OPERATION RESULT --- Gross: -1.23, Net: -1.23
# 2018-04-12, BUY CREATED --- Price: 244.28
# 2018-04-13, BUY EXECUTED --- Price: 245.84, Cost: 245.84, Commission: 0.00
# 2018-04-24, SELL CREATED --- Price: 241.55
# 2018-04-25, SELL EXECUTED --- Price: 241.51, Cost: 245.84, Commission: 0.00
# 2018-04-25, OPERATION RESULT --- Gross: -4.33, Net: -4.33
# 2018-04-26, BUY CREATED --- Price: 244.66
# 2018-04-27, BUY EXECUTED --- Price: 245.23, Cost: 245.23, Commission: 0.00
# 2018-04-30, SELL CREATED --- Price: 242.92
# 2018-05-01, SELL EXECUTED --- Price: 242.45, Cost: 245.23, Commission: 0.00
# 2018-05-01, OPERATION RESULT --- Gross: -2.78, Net: -2.78
# 2018-05-04, BUY CREATED --- Price: 244.41
# 2018-05-07, BUY EXECUTED --- Price: 245.19, Cost: 245.19, Commission: 0.00
# 2018-05-29, SELL CREATED --- Price: 247.15
# 2018-05-30, SELL EXECUTED --- Price: 248.53, Cost: 245.19, Commission: 0.00
# 2018-05-30, OPERATION RESULT --- Gross: 3.34, Net: 3.34
# 2018-05-30, BUY CREATED --- Price: 250.41
# 2018-05-31, BUY EXECUTED --- Price: 249.99, Cost: 249.99, Commission: 0.00
# 2018-06-21, SELL CREATED --- Price: 253.12
# 2018-06-22, SELL EXECUTED --- Price: 254.40, Cost: 249.99, Commission: 0.00
# 2018-06-22, OPERATION RESULT --- Gross: 4.41, Net: 4.41
# 2018-06-22, BUY CREATED --- Price: 253.57
# 2018-06-25, BUY EXECUTED --- Price: 252.37, Cost: 252.37, Commission: 0.00
# 2018-06-25, SELL CREATED --- Price: 250.06
# 2018-06-26, SELL EXECUTED --- Price: 250.66, Cost: 252.37, Commission: 0.00
# 2018-06-26, OPERATION RESULT --- Gross: -1.71, Net: -1.71
# 2018-07-06, BUY CREATED --- Price: 253.01
# 2018-07-09, BUY EXECUTED --- Price: 254.05, Cost: 254.05, Commission: 0.00
# 2018-08-13, SELL CREATED --- Price: 259.14
# 2018-08-14, SELL EXECUTED --- Price: 259.94, Cost: 254.05, Commission: 0.00
# 2018-08-14, OPERATION RESULT --- Gross: 5.89, Net: 5.89
# 2018-08-14, BUY CREATED --- Price: 260.81
# 2018-08-15, BUY EXECUTED --- Price: 259.43, Cost: 259.43, Commission: 0.00
# 2018-08-15, SELL CREATED --- Price: 258.89
# 2018-08-16, SELL EXECUTED --- Price: 260.36, Cost: 259.43, Commission: 0.00
# 2018-08-16, OPERATION RESULT --- Gross: 0.93, Net: 0.93
# 2018-08-16, BUY CREATED --- Price: 260.99
# 2018-08-17, BUY EXECUTED --- Price: 260.71, Cost: 260.71, Commission: 0.00
# 2018-09-26, SELL CREATED --- Price: 266.34
# 2018-09-27, SELL EXECUTED --- Price: 266.88, Cost: 260.71, Commission: 0.00
# 2018-09-27, OPERATION RESULT --- Gross: 6.17, Net: 6.17
# 2018-09-27, BUY CREATED --- Price: 267.08
# 2018-09-28, BUY EXECUTED --- Price: 266.50, Cost: 266.50, Commission: 0.00
# 2018-10-04, SELL CREATED --- Price: 266.04
# 2018-10-05, SELL EXECUTED --- Price: 266.19, Cost: 266.50, Commission: 0.00
# 2018-10-05, OPERATION RESULT --- Gross: -0.31, Net: -0.31
# 2018-11-06, BUY CREATED --- Price: 252.82
# 2018-11-07, BUY EXECUTED --- Price: 255.07, Cost: 255.07, Commission: 0.00
# 2018-11-12, SELL CREATED --- Price: 250.41
# 2018-11-13, SELL EXECUTED --- Price: 250.96, Cost: 255.07, Commission: 0.00
# 2018-11-13, OPERATION RESULT --- Gross: -4.11, Net: -4.11
# 2018-11-15, BUY CREATED --- Price: 250.85
# 2018-11-16, BUY EXECUTED --- Price: 249.77, Cost: 249.77, Commission: 0.00
# 2018-11-19, SELL CREATED --- Price: 247.32
# 2018-11-20, SELL EXECUTED --- Price: 243.84, Cost: 249.77, Commission: 0.00
# 2018-11-20, OPERATION RESULT --- Gross: -5.93, Net: -5.93
# 2018-11-28, BUY CREATED --- Price: 252.33
# 2018-11-29, BUY EXECUTED --- Price: 251.54, Cost: 251.54, Commission: 0.00
# 2018-12-04, SELL CREATED --- Price: 248.65
# 2018-12-06, SELL EXECUTED --- Price: 244.42, Cost: 251.54, Commission: 0.00
# 2018-12-06, OPERATION RESULT --- Gross: -7.12, Net: -7.12
# 2019-01-07, BUY CREATED --- Price: 233.65
# 2019-01-08, BUY EXECUTED --- Price: 236.05, Cost: 236.05, Commission: 0.00
# 2019-03-07, SELL CREATED --- Price: 252.85
# 2019-03-08, SELL EXECUTED --- Price: 250.88, Cost: 236.05, Commission: 0.00
# 2019-03-08, OPERATION RESULT --- Gross: 14.83, Net: 14.83
# 2019-03-11, BUY CREATED --- Price: 256.02
# 2019-03-12, BUY EXECUTED --- Price: 256.52, Cost: 256.52, Commission: 0.00
# 2019-03-22, SELL CREATED --- Price: 256.46
# 2019-03-25, SELL EXECUTED --- Price: 256.09, Cost: 256.52, Commission: 0.00
# 2019-03-25, OPERATION RESULT --- Gross: -0.43, Net: -0.43
# 2019-03-26, BUY CREATED --- Price: 258.08
# 2019-03-27, BUY EXECUTED --- Price: 258.15, Cost: 258.15, Commission: 0.00
# 2019-03-27, SELL CREATED --- Price: 256.88
# 2019-03-28, SELL EXECUTED --- Price: 257.45, Cost: 258.15, Commission: 0.00
# 2019-03-28, OPERATION RESULT --- Gross: -0.70, Net: -0.70
# 2019-03-28, BUY CREATED --- Price: 257.88
# 2019-03-29, BUY EXECUTED --- Price: 259.34, Cost: 259.34, Commission: 0.00
# 2019-05-07, SELL CREATED --- Price: 264.62
# 2019-05-08, SELL EXECUTED --- Price: 264.14, Cost: 259.34, Commission: 0.00
# 2019-05-08, OPERATION RESULT --- Gross: 4.80, Net: 4.80
# 2019-06-05, BUY CREATED --- Price: 259.85
# 2019-06-06, BUY EXECUTED --- Price: 260.17, Cost: 260.17, Commission: 0.00
# 2019-07-31, SELL CREATED --- Price: 273.08
# 2019-08-01, SELL EXECUTED --- Price: 273.28, Cost: 260.17, Commission: 0.00
# 2019-08-01, OPERATION RESULT --- Gross: 13.11, Net: 13.11
# 2019-08-21, BUY CREATED --- Price: 268.56
# 2019-08-22, BUY EXECUTED --- Price: 269.28, Cost: 269.28, Commission: 0.00
# 2019-08-23, SELL CREATED --- Price: 261.57
# 2019-08-26, SELL EXECUTED --- Price: 263.81, Cost: 269.28, Commission: 0.00
# 2019-08-26, OPERATION RESULT --- Gross: -5.47, Net: -5.47
# 2019-08-29, BUY CREATED --- Price: 268.71
# 2019-08-30, BUY EXECUTED --- Price: 270.15, Cost: 270.15, Commission: 0.00
# 2019-09-26, SELL CREATED --- Price: 272.79
# 2019-09-27, SELL EXECUTED --- Price: 273.56, Cost: 270.15, Commission: 0.00
# 2019-09-27, OPERATION RESULT --- Gross: 3.41, Net: 3.41
# 2019-10-11, BUY CREATED --- Price: 272.13
# 2019-10-14, BUY EXECUTED --- Price: 271.79, Cost: 271.79, Commission: 0.00
# 2019-12-03, SELL CREATED --- Price: 284.29
# 2019-12-04, SELL EXECUTED --- Price: 285.41, Cost: 271.79, Commission: 0.00
# 2019-12-04, OPERATION RESULT --- Gross: 13.62, Net: 13.62
# 2019-12-04, BUY CREATED --- Price: 286.11
# 2019-12-05, BUY EXECUTED --- Price: 286.83, Cost: 286.83, Commission: 0.00
# 2020-01-27, SELL CREATED --- Price: 297.23
# 2020-01-28, SELL EXECUTED --- Price: 298.70, Cost: 286.83, Commission: 0.00
# 2020-01-28, OPERATION RESULT --- Gross: 11.87, Net: 11.87
# 2020-01-28, BUY CREATED --- Price: 300.45
# 2020-01-29, BUY EXECUTED --- Price: 301.78, Cost: 301.78, Commission: 0.00
# 2020-01-29, SELL CREATED --- Price: 300.15
# 2020-01-30, SELL EXECUTED --- Price: 298.04, Cost: 301.78, Commission: 0.00
# 2020-01-30, OPERATION RESULT --- Gross: -3.74, Net: -3.74
# 2020-01-30, BUY CREATED --- Price: 301.09
# 2020-01-31, BUY EXECUTED --- Price: 300.44, Cost: 300.44, Commission: 0.00
# 2020-01-31, SELL CREATED --- Price: 295.69
# 2020-02-03, SELL EXECUTED --- Price: 297.12, Cost: 300.44, Commission: 0.00
# 2020-02-03, OPERATION RESULT --- Gross: -3.32, Net: -3.32
# 2020-02-04, BUY CREATED --- Price: 302.43
# 2020-02-05, BUY EXECUTED --- Price: 305.40, Cost: 305.40, Commission: 0.00
# 2020-02-24, SELL CREATED --- Price: 296.24
# 2020-02-25, SELL EXECUTED --- Price: 297.73, Cost: 305.40, Commission: 0.00
# 2020-02-25, OPERATION RESULT --- Gross: -7.67, Net: -7.67
# 2020-04-06, BUY CREATED --- Price: 243.53
# 2020-04-07, BUY EXECUTED --- Price: 251.92, Cost: 251.92, Commission: 0.00
# 2020-05-13, SELL CREATED --- Price: 258.74
# 2020-05-14, SELL EXECUTED --- Price: 256.33, Cost: 251.92, Commission: 0.00
# 2020-05-14, OPERATION RESULT --- Gross: 4.41, Net: 4.41
# 2020-05-15, BUY CREATED --- Price: 263.04
# 2020-05-18, BUY EXECUTED --- Price: 269.32, Cost: 269.32, Commission: 0.00
# 2020-06-11, SELL CREATED --- Price: 276.32
# 2020-06-12, SELL EXECUTED --- Price: 283.35, Cost: 269.32, Commission: 0.00
# 2020-06-12, OPERATION RESULT --- Gross: 14.03, Net: 14.03
# 2020-06-15, BUY CREATED --- Price: 282.20
# 2020-06-16, BUY EXECUTED --- Price: 290.05, Cost: 290.05, Commission: 0.00
# 2020-06-24, SELL CREATED --- Price: 280.79
# 2020-06-25, SELL EXECUTED --- Price: 280.26, Cost: 290.05, Commission: 0.00
# 2020-06-25, OPERATION RESULT --- Gross: -9.79, Net: -9.79
# 2020-07-02, BUY CREATED --- Price: 286.81
# 2020-07-06, BUY EXECUTED --- Price: 290.67, Cost: 290.67, Commission: 0.00
# 2020-09-04, SELL CREATED --- Price: 314.82
# 2020-09-08, SELL EXECUTED --- Price: 309.35, Cost: 290.67, Commission: 0.00
# 2020-09-08, OPERATION RESULT --- Gross: 18.68, Net: 18.68
# 2020-10-01, BUY CREATED --- Price: 309.60
# 2020-10-02, BUY EXECUTED --- Price: 304.72, Cost: 304.72, Commission: 0.00
# 2020-10-02, SELL CREATED --- Price: 306.72
# 2020-10-05, SELL EXECUTED --- Price: 308.69, Cost: 304.72, Commission: 0.00
# 2020-10-05, OPERATION RESULT --- Gross: 3.97, Net: 3.97
# 2020-10-05, BUY CREATED --- Price: 312.08
# 2020-10-06, BUY EXECUTED --- Price: 312.25, Cost: 312.25, Commission: 0.00
# 2020-10-26, SELL CREATED --- Price: 311.80
# 2020-10-27, SELL EXECUTED --- Price: 312.18, Cost: 312.25, Commission: 0.00
# 2020-10-27, OPERATION RESULT --- Gross: -0.07, Net: -0.07
# 2020-11-04, BUY CREATED --- Price: 315.61
# 2020-11-05, BUY EXECUTED --- Price: 320.94, Cost: 320.94, Commission: 0.00
# 2021-01-04, SELL CREATED --- Price: 339.03
# 2021-01-05, SELL EXECUTED --- Price: 338.40, Cost: 320.94, Commission: 0.00
# 2021-01-05, OPERATION RESULT --- Gross: 17.46, Net: 17.46
# 2021-01-05, BUY CREATED --- Price: 341.26
# 2021-01-06, BUY EXECUTED --- Price: 339.79, Cost: 339.79, Commission: 0.00
# 2021-01-27, SELL CREATED --- Price: 344.24
# 2021-01-28, SELL EXECUTED --- Price: 345.97, Cost: 339.79, Commission: 0.00
# 2021-01-28, OPERATION RESULT --- Gross: 6.18, Net: 6.18
# 2021-02-02, BUY CREATED --- Price: 350.74
# 2021-02-03, BUY EXECUTED --- Price: 351.70, Cost: 351.70, Commission: 0.00
# 2021-02-25, SELL CREATED --- Price: 351.52
# 2021-02-26, SELL EXECUTED --- Price: 353.47, Cost: 351.70, Commission: 0.00
# 2021-02-26, OPERATION RESULT --- Gross: 1.77, Net: 1.77
# 2021-03-01, BUY CREATED --- Price: 358.12
# 2021-03-02, BUY EXECUTED --- Price: 358.38, Cost: 358.38, Commission: 0.00
# 2021-03-02, SELL CREATED --- Price: 355.35
# 2021-03-03, SELL EXECUTED --- Price: 354.70, Cost: 358.38, Commission: 0.00
# 2021-03-03, OPERATION RESULT --- Gross: -3.68, Net: -3.68
# 2021-03-10, BUY CREATED --- Price: 358.07
# 2021-03-11, BUY EXECUTED --- Price: 360.66, Cost: 360.66, Commission: 0.00
# 2021-05-11, SELL CREATED --- Price: 380.86
# 2021-05-12, SELL EXECUTED --- Price: 378.04, Cost: 360.66, Commission: 0.00
# 2021-05-12, OPERATION RESULT --- Gross: 17.38, Net: 17.38
# 2021-05-14, BUY CREATED --- Price: 382.95
# 2021-05-17, BUY EXECUTED --- Price: 381.90, Cost: 381.90, Commission: 0.00
# 2021-05-17, SELL CREATED --- Price: 382.03
# 2021-05-18, SELL EXECUTED --- Price: 382.25, Cost: 381.90, Commission: 0.00
# 2021-05-18, OPERATION RESULT --- Gross: 0.35, Net: 0.35
# 2021-05-24, BUY CREATED --- Price: 385.32
# 2021-05-25, BUY EXECUTED --- Price: 386.40, Cost: 386.40, Commission: 0.00
# 2021-06-18, SELL CREATED --- Price: 382.82
# 2021-06-21, SELL EXECUTED --- Price: 384.50, Cost: 386.40, Commission: 0.00
# 2021-06-21, OPERATION RESULT --- Gross: -1.90, Net: -1.90
# 2021-06-21, BUY CREATED --- Price: 388.18
# 2021-06-22, BUY EXECUTED --- Price: 388.24, Cost: 388.24, Commission: 0.00
# 2021-07-19, SELL CREATED --- Price: 390.68
# 2021-07-20, SELL EXECUTED --- Price: 391.35, Cost: 388.24, Commission: 0.00
# 2021-07-20, OPERATION RESULT --- Gross: 3.11, Net: 3.11
# 2021-07-20, BUY CREATED --- Price: 396.20
# 2021-07-21, BUY EXECUTED --- Price: 397.48, Cost: 397.48, Commission: 0.00
# 2021-08-18, SELL CREATED --- Price: 403.84
# 2021-08-19, SELL EXECUTED --- Price: 401.09, Cost: 397.48, Commission: 0.00
# 2021-08-19, OPERATION RESULT --- Gross: 3.61, Net: 3.61
# 2021-08-20, BUY CREATED --- Price: 407.61
# 2021-08-23, BUY EXECUTED --- Price: 409.25, Cost: 409.25, Commission: 0.00
# 2021-09-10, SELL CREATED --- Price: 409.58
# 2021-09-13, SELL EXECUTED --- Price: 412.52, Cost: 409.25, Commission: 0.00
# 2021-09-13, OPERATION RESULT --- Gross: 3.27, Net: 3.27
# 2021-10-14, BUY CREATED --- Price: 406.76
# 2021-10-15, BUY EXECUTED --- Price: 408.92, Cost: 408.92, Commission: 0.00
# 2021-11-26, SELL CREATED --- Price: 422.14
# 2021-11-29, SELL EXECUTED --- Price: 426.71, Cost: 408.92, Commission: 0.00
# 2021-11-29, OPERATION RESULT --- Gross: 17.79, Net: 17.79
# 2021-12-07, BUY CREATED --- Price: 430.49
# 2021-12-08, BUY EXECUTED --- Price: 430.95, Cost: 430.95, Commission: 0.00
# 2021-12-14, SELL CREATED --- Price: 426.09
# 2021-12-15, SELL EXECUTED --- Price: 426.11, Cost: 430.95, Commission: 0.00
# 2021-12-15, OPERATION RESULT --- Gross: -4.84, Net: -4.84
# 2021-12-15, BUY CREATED --- Price: 432.75
# 2021-12-16, BUY EXECUTED --- Price: 434.56, Cost: 434.56, Commission: 0.00
# 2021-12-17, SELL CREATED --- Price: 424.39
# 2021-12-20, SELL EXECUTED --- Price: 419.39, Cost: 434.56, Commission: 0.00
# 2021-12-20, OPERATION RESULT --- Gross: -15.17, Net: -15.17
# 2021-12-22, BUY CREATED --- Price: 429.99
# 2021-12-23, BUY EXECUTED --- Price: 430.91, Cost: 430.91, Commission: 0.00
# 2022-01-05, SELL CREATED --- Price: 430.66
# 2022-01-06, SELL EXECUTED --- Price: 430.20, Cost: 430.91, Commission: 0.00
# 2022-01-06, OPERATION RESULT --- Gross: -0.71, Net: -0.71
# 2022-01-12, BUY CREATED --- Price: 433.07
# 2022-01-13, BUY EXECUTED --- Price: 434.09, Cost: 434.09, Commission: 0.00
# 2022-01-13, SELL CREATED --- Price: 427.10
# 2022-01-14, SELL EXECUTED --- Price: 423.95, Cost: 434.09, Commission: 0.00
# 2022-01-14, OPERATION RESULT --- Gross: -10.14, Net: -10.14
# 2022-02-02, BUY CREATED --- Price: 420.36
# 2022-02-03, BUY EXECUTED --- Price: 414.59, Cost: 414.59, Commission: 0.00
# 2022-02-03, SELL CREATED --- Price: 410.59
# 2022-02-04, SELL EXECUTED --- Price: 410.34, Cost: 414.59, Commission: 0.00
# 2022-02-04, OPERATION RESULT --- Gross: -4.25, Net: -4.25
# 2022-02-08, BUY CREATED --- Price: 414.49
# 2022-02-09, BUY EXECUTED --- Price: 418.55, Cost: 418.55, Commission: 0.00
# 2022-02-11, SELL CREATED --- Price: 404.94
# 2022-02-14, SELL EXECUTED --- Price: 404.43, Cost: 418.55, Commission: 0.00
# 2022-02-14, OPERATION RESULT --- Gross: -14.12, Net: -14.12
# 2022-02-15, BUY CREATED --- Price: 410.10
# 2022-02-16, BUY EXECUTED --- Price: 408.20, Cost: 408.20, Commission: 0.00
# 2022-02-17, SELL CREATED --- Price: 401.86
# 2022-02-18, SELL EXECUTED --- Price: 402.15, Cost: 408.20, Commission: 0.00
# 2022-02-18, OPERATION RESULT --- Gross: -6.05, Net: -6.05
# Final Portfolio Value: 1056.93

# %%
# %load backtrader_sma_strategy_optimization.py
from datetime import datetime
import backtrader as bt

# Create a Stratey
class SmaStrategy(bt.Strategy):
    params = (('ma_period', 20),)

    def __init__(self):
        # keep track of close price in the series
        self.data_close = self.datas[0].close

        # keep track of pending orders
        self.order = None

        # add a simple moving average indicator
        self.sma = bt.ind.SMA(self.datas[0], period=self.params.ma_period)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        # set no pending order
        self.order = None

    def next(self):
        # do nothing if an order is pending
        if self.order:
            return

        # check if there is already a position
        if not self.position:
            # buy condition
            if self.data_close[0] > self.sma[0]:
                self.order = self.buy()
        else:
            # sell condition
            if self.data_close[0] < self.sma[0]:
                self.order = self.sell()

    def stop(self):
        self.log(f'(ma_period = {self.params.ma_period:2d}) --- Terminal Value: {self.broker.getvalue():.2f}')
        
    data = bt.feeds.PandasData(dataname=yf.download('VOO', '2021-02-22', '2022-02-22'))
    
    # create a Cerebro entity
cerebro = bt.Cerebro(stdstats = False)

# set up the backtest
cerebro.adddata(data)
cerebro.optstrategy(SmaStrategy, ma_period=range(10, 31))
cerebro.broker.setcash(1000.0)
cerebro.run(maxcpus=4)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import backtrader as bt
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
class BBand_Strategy(bt.Strategy):
    params = (('period', 20),
              ('devfactor', 2.0),)

    def __init__(self):
        # keep track of close price in the series
        self.data_close = self.datas[0].close
        self.data_open = self.datas[0].open

        # keep track of pending orders/buy price/buy commission
        self.order = None
        self.price = None
        self.comm = None

        # add Bollinger Bands indicator and track the buy/sell signals
        self.b_band = bt.ind.BollingerBands(self.datas[0], 
                                            period=self.p.period, 
                                            devfactor=self.p.devfactor)
        self.buy_signal = bt.ind.CrossOver(self.datas[0], 
                                           self.b_band.lines.bot)
        self.sell_signal = bt.ind.CrossOver(self.datas[0], 
                                            self.b_band.lines.top)

    def log(self, txt):
        '''Logging function'''
        dt = self.datas[0].datetime.date(0).isoformat()
        print(f'{dt}, {txt}')

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # order already submitted/accepted - no action required
            return

        # report executed order
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    f'BUY EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Commission: {order.executed.comm:.2f}'
                )
                self.price = order.executed.price
                self.comm = order.executed.comm
            else:
                self.log(
                    f'SELL EXECUTED --- Price: {order.executed.price:.2f}, Cost: {order.executed.value:.2f}, Commission: {order.executed.comm:.2f}'
                )

        # report failed order
        elif order.status in [order.Canceled, order.Margin, 
                              order.Rejected]:
            self.log('Order Failed')

            # set no pending order
        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log(f'OPERATION RESULT --- Gross: {trade.pnl:.2f}, Net: {trade.pnlcomm:.2f}')

    def next_open(self):
        if not self.position:
            if self.buy_signal > 0:
                # calculate the max number of shares ('all-in')
                size = int(self.broker.getcash() / self.datas[0].open)
                # buy order
                self.log(f'BUY CREATED --- Size: {size}, Cash: {self.broker.getcash():.2f}, Open: {self.data_open[0]}, Close: {self.data_close[0]}')
                self.buy(size=size)
        else:
            if self.sell_signal < 0:
                # sell order
                self.log(f'SELL CREATED --- Size: {self.position.size}')
                self.sell(size=self.position.size)

# %%
data = bt.feeds.PandasData(dataname=yf.download('VOO', '2021-02-22', '2022-02-22'))

# %%
cerebro = bt.Cerebro(stdstats = False, cheat_on_open=True)

cerebro.addstrategy(BBand_Strategy)
cerebro.adddata(data)
cerebro.broker.setcash(10000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)
cerebro.addanalyzer(bt.analyzers.Returns, _name='returns')
cerebro.addanalyzer(bt.analyzers.TimeReturn, _name='time_return')

# %%
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
backtest_result = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

# %%
cerebro.plot(iplot=True, volume=False)
